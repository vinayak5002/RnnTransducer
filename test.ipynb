# %%
with open('./files/vocab_to_int.txt', 'r') as f:
    vocab = f.read().split('\n')

# %%
vocab
# Out:
# ['requiring 2',
#  'britain 3',
#  'provoked 4',
#  'ticketholders 5',
#  'stuck 6',
#  'twice 7',
#  'troyekurovskoye 8',
#  'interred 9',
#  'necessary 10',
#  'milwaukee 11',
#  'describe 12',
#  'kennedy 13',
#  'octavia 14',
#  'cobden 15',
#  'marshall 16',
#  'illuminatus 17',
#  'hochschule 18',
#  'improved 19',
#  'expedition 20',
#  'cologne 21',
#  'refers 22',
#  'alun 23',
#  'bolton 24',
#  'ballew 25',
#  'hassett 26',
#  'parrots 27',
#  'shops 28',
#  'externally 29',
#  'liz 30',
#  'bracing 31',
#  'caramel 32',
#  'gentry 33',
#  'agents 34',
#  'attackers 35',
#  'grandview 36',
#  'fuchsia 37',
#  'spine 38',
#  'covers 39',
#  'calderas 40',
#  'inhabitants 41',
#  'cooking 42',
#  'slang 43',
#  'cummings 44',
#  'fun 45',
#  'disappeared 46',
#  'untrue 47',
#  'competition 48',
#  'liberal 49',
#  'vertical 50',
#  'girdle 51',
#  'controls 52',
#  'bottom 53',
#  'yate 54',
#  'worship 55',
#  'decrepit 56',
#  'decades 57',
#  'hospital 58',
# ...
